# %% [markdown]
# 패키지 세팅!

# %%
# 구글드라이브 마운트 & VS Code로 requirements.txt 작성해서 구글드라이브에 업로드
from google.colab import drive
drive.mount('/content/drive')  # Google Drive를 마운트 (선택 사항)

# %%
#!find /content/drive/MyDrive -name "requirements.txt"

# %%
# !pip install -r "/content/drive/MyDrive/Colab Notebooks/quant_py/requirements.txt"

# %%
# !pip uninstall decorator -y
# !pip uninstall jedi -y

# %%
# !pip install decorator==4.4.2
# !pip install jedi==0.18.2
